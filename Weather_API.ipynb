# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '405f0c57-21fb-45d6-a1c8-cff89c617879',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# HTTPSConnectionPool(host='pro-api.coinmarketcap.com', port=443): Max retries exceeded with url: /v1/cryptocurrency/listings/latest?start=1&limit=5000&convert=USD (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000019A0EE55F40>: Failed to resolve 'pro-api.coinmarketcap.com' ([Errno 11001] getaddrinfo failed)"))

# %%
tyep(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tyep(data)
#
# NameError: name 'tyep' is not defined

# %%
type(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 type(data)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
pd.json_normalize(data['data'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.json_normalize(data['data'])
#
# NameError: name 'data' is not defined

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '58f4a8c8-c2fa-401e-b51f-d860139eb0b4',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video
# Out:
# HTTPSConnectionPool(host='pro-api.coinmarketcap.com', port=443): Max retries exceeded with url: /v1/cryptocurrency/listings/latest?start=1&limit=5000&convert=USD (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000019A0F0F46E0>: Failed to resolve 'pro-api.coinmarketcap.com' ([Errno 11001] getaddrinfo failed)"))

# %%
type(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 type(data)
#
# NameError: name 'data' is not defined

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df = pd.json_normalize(data['data'])
#       2 df['timestamp'] = pd.to_datetime('now')
#       3 df
#
# NameError: name 'data' is not defined

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
parameters = {
    'start': '1',
    'limit': '5000',
    'convert': 'USD'
}
headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': '58f4a8c8-c2fa-401e-b51f-d860139eb0b4',
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    if response.status_code == 200:  # Ensure the request was successful
        data = json.loads(response.text)
        print(data)  # Inspect the data
    else:
        print(f"Error: Received status code {response.status_code}")
except (ConnectionError, Timeout, TooManyRedirects) as e:
    print(f"Request failed: {e}")

# Check if `data` is defined
if 'data' in locals():
    print("Type of data:", type(data))
else:
    print("The `data` variable was not created due to a request failure.")
# Out:
# Request failed: HTTPSConnectionPool(host='pro-api.coinmarketcap.com', port=443): Max retries exceeded with url: /v1/cryptocurrency/listings/latest?start=1&limit=5000&convert=USD (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000019A0F0F7DD0>: Failed to resolve 'pro-api.coinmarketcap.com' ([Errno 11001] getaddrinfo failed)"))
# The `data` variable was not created due to a request failure.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://api.weatherbit.io/v2.0/history/daily'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd2f16f6882ca73bef5a41ee211d5294c',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'error': 'API key is required.'}

# %%
from requests import Session
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
    'start': '1',
    'limit': '10',
    'convert': 'USD'
}
headers = {
    'Accepts': 'application/json',
    'X-CMC_PRO_API_KEY': '58f4a8c8-c2fa-401e-b51f-d860139eb0b4',  # Replace with your actual API key
}

session = Session()
session.headers.update(headers)

try:
    response = session.get(url, params=parameters)
    data = json.loads(response.text)
    print(json.dumps(data, indent=4))
except Exception as e:
    print(e)
# Out:
# {
#     "status": {
#         "timestamp": "2025-01-18T22:06:39.621Z",
#         "error_code": 0,
#         "error_message": null,
#         "elapsed": 866,
#         "credit_count": 1,
#         "notice": null,
#         "total_count": 10693
#     },
#     "data": [
#         {
#             "id": 1,
#             "name": "Bitcoin",
#             "symbol": "BTC",
#             "slug": "bitcoin",
#             "num_market_pairs": 11868,
#             "date_added": "2010-07-13T00:00:00.000Z",
#             "tags": [
#                 "mineable",
#                 "pow",
#                 "sha-256",
#                 "store-of-value",
#                 "state-channel",
#                 "coinbase-ventures-portfolio",
#                 "three-arrows-capital-portfolio",
#                 "polychain-capital-portfolio",
#                 "binance-labs-portfolio",
#                 "blockchain-capital-portfolio",
#                 "boostvc-portfolio",
# ...

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://api.openweathermap.org/data/2.5/weather?q=London&appid=1b5c6b7425c408e2021df8472f49e460' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'50',
  'convert':'USD'
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

pd.json_normalize(data['data'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 3
#       1 #This normalizes the data and makes it all pretty in a dataframe
# ----> 3 pd.json_normalize(data['data'])
#
# KeyError: 'data'

# %%
import pandas as pd

# Assuming 'data' is a dictionary from OpenWeather API
weather_data = data  # This will be the entire response dictionary

# You can normalize parts of the data if needed
# For example, extracting 'main' data like temperature, pressure, etc.
df = pd.json_normalize(weather_data['main'])

# Show all columns
pd.set_option('display.max_columns', None)

# Print the resulting DataFrame
print(df)
# Out:
#      temp  feels_like  temp_min  temp_max  pressure  humidity  sea_level  \
# 0  271.76      271.76    270.32    272.64      1037        95       1037
#
#    grnd_level
# 0        1033

# %%
import json
print(json.dumps(data, indent=4))
# Out:
# {
#     "cod": 401,
#     "message": "Invalid API key. Please see https://openweathermap.org/faq#error401 for more info."
# }

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://api.openweathermap.org/data/2.5/weather?q=usa&appid=1b5c6b7425c408e2021df8472f49e460' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'50',
  'convert':'USD'
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
print(data)
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 276.99, 'feels_like': 274.61, 'temp_min': 274.87, 'temp_max': 278.01, 'pressure': 1013, 'humidity': 92, 'sea_level': 1013, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 2.57, 'deg': 320}, 'clouds': {'all': 75}, 'dt': 1735787101, 'sys': {'type': 2, 'id': 2075535, 'country': 'GB', 'sunrise': 1735805158, 'sunset': 1735833770}, 'timezone': 0, 'id': 2643743, 'name': 'London', 'cod': 200}

# %%
pd.json_normalize(data['visibility'])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 pd.json_normalize(data['visibility'])
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
#     451     record_path is None
#     452     and meta is None
#    (...)
#     455     and max_level is None
#     456 ):
#
# NotImplementedError:

# %%
import pandas as pd

# Extracting and normalizing relevant parts of the data
df = pd.json_normalize(data, sep='_')  # This flattens the nested structure

# Display the DataFrame
print(df)
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 804, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone      id       name  cod  coord_lon  coord_lat  ...  \
# 0  1737238426     10800  149155  Usa River  200      36.85    -3.3667  ...
#
#    main_humidity  main_sea_level  main_grnd_level  wind_speed  wind_deg  \
# 0             71            1013              883        0.78       301
#
#    wind_gust  clouds_all  sys_country  sys_sunrise  sys_sunset
# 0       1.57          90           TZ   1737257675  1737301900
#
# [1 rows x 25 columns]

# %%
# Normalizing weather data (which is a list of dictionaries)
weather_df = pd.json_normalize(data['weather'], sep='_')

# Normalizing 'main' data (temperature, humidity, etc.)
main_df = pd.json_normalize(data['main'], sep='_')

# Normalizing wind data (wind speed, direction, etc.)
wind_df = pd.json_normalize(data['wind'], sep='_')

# Normalizing system data (sunrise, sunset, country code)
sys_df = pd.json_normalize(data['sys'], sep='_')

# Display the DataFrames
print(weather_df)
print(main_df)
print(wind_df)
print(sys_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Normalizing weather data (which is a list of dictionaries)
# ----> 2 weather_df = pd.json_normalize(data['weather'], sep='_')
#       4 # Normalizing 'main' data (temperature, humidity, etc.)
#       5 main_df = pd.json_normalize(data['main'], sep='_')
#
# NameError: name 'pd' is not defined

# %%
import requests
import os
from datetime import datetime

user_api = os.environ['current_weather_data']
location = input("Enter the city name: ")

complete_api_link = f"https://api.openweathermap.org/data/2.5/weather?q="+location+"&appid="1b5c6b7425c408e2021df8472f49e460"
api_link = requests.get(complete_api_link)
api_data = api_link.json()
print(api_data)
# Out:
#   Cell In[30], line 8
#     complete_api_link = f"https://api.openweathermap.org/data/2.5/weather?q="+location+"&appid="1b5c6b7425c408e2021df8472f49e460"
#                                                                                                 ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd
import os
import requests
from datetime import datetime

# List of 25 state names (or cities if needed)
states = [
    "California", "Texas", "Florida", "New York", "Illinois",
    "Pennsylvania", "Ohio", "Georgia", "North Carolina", "Michigan",
    "New Jersey", "Virginia", "Washington", "Arizona", "Massachusetts",
    "Tennessee", "Indiana", "Missouri", "Maryland", "Wisconsin",
    "Colorado", "Minnesota", "South Carolina", "Alabama", "Louisiana", "Kentucky"
]

# Assuming the weather data API setup is already correct
user_api = os.environ.get('current_weather_data', '1b5c6b7425c408e2021df8472f49e460')  # Replace with your API key
file_path = r"C:\Users\dilee\Downloads\weather_data.csv"

# Loop through each state
for state in states:
    # Build the complete API link
    complete_api_link = f"https://api.openweathermap.org/data/2.5/weather?q={state}&appid={user_api}"
    api_link = requests.get(complete_api_link)
    api_data = api_link.json()

    # Check if the response is valid (status code 200)
    if api_data['cod'] == 200:
        # Extracting and converting the data
        latitude = api_data['coord']['lat']
        longitude = api_data['coord']['lon']
        weather_desc = api_data['weather'][0]['description']
        temp_kelvin = api_data['main']['temp']
        temp_city_celsius = temp_kelvin - 273.15
        temp_city_fahrenheit = (temp_city_celsius * 9/5) + 32
        humidity = api_data['main']['humidity']
        wind_speed = api_data['wind']['speed']
        cloud_coverage = api_data['clouds']['all']
        pressure = api_data['main']['pressure']
        timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")

        # Creating the data for the new row
        data = {
            'Location': [state],
            'Latitude': [latitude],
            'Longitude': [longitude],
            'Weather Description': [weather_desc],
            'Temperature (°C)': [temp_city_celsius],
            'Temperature (°F)': [temp_city_fahrenheit],
            'Humidity (%)': [humidity],
            'Wind Speed (km/h)': [wind_speed],
            'Cloud Coverage (%)': [cloud_coverage],
            'Pressure (hPa)': [pressure],
            'Date & Time': [timestamp]
        }

        df = pd.DataFrame(data)

        # Check if the file already exists to decide whether to write the header or not
        if os.path.exists(file_path):
            # Append the data without writing the header
            df.to_csv(file_path, mode='a', header=False, index=False)
        else:
            # Write the data with the header
            df.to_csv(file_path, mode='w', header=True, index=False)

        print(f"Data for {state} saved successfully!")
    else:
        print(f"Failed to get data for {state}.")
# Out:
# Data for California saved successfully!
# Data for Texas saved successfully!
# Data for Florida saved successfully!
# Data for New York saved successfully!
# Data for Illinois saved successfully!
# Data for Pennsylvania saved successfully!
# Data for Ohio saved successfully!
# Data for Georgia saved successfully!
# Data for North Carolina saved successfully!
# Data for Michigan saved successfully!
# Data for New Jersey saved successfully!
# Data for Virginia saved successfully!
# Data for Washington saved successfully!
# Data for Arizona saved successfully!
# Data for Massachusetts saved successfully!
# Data for Tennessee saved successfully!
# Data for Indiana saved successfully!
# Data for Missouri saved successfully!
# Data for Maryland saved successfully!
# Data for Wisconsin saved successfully!
# Data for Colorado saved successfully!
# Data for Minnesota saved successfully!
# Data for South Carolina saved successfully!
# Data for Alabama saved successfully!
# ...
